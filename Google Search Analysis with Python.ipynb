# %% [markdown]
# # Google Search Analysis with Python

# %%
pip install pytrends
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# **Here I will be analyzing the Google search trends on the queries based on “Artificial Intelligence”**

# %% [markdown]
# **Creating a DataFrame of the top 10 countries which search for “Artificial Intelligence” on Google**

# %%
trends.build_payload(kw_list=["Artificial Intelligence"])
data = trends.interest_by_region()
data = data.sort_values(by="Artificial Intelligence", ascending=False)
data = data.head(10)
print(data)
# Out:
#                       Artificial Intelligence
# geoName
# Ethiopia                                  100
# Bhutan                                     58
# China                                      51
# United Arab Emirates                       46
# Botswana                                   46
# Ghana                                      36
# Brunei                                     27
# Bahrain                                    26
# Bangladesh                                 25
# Cyprus                                     21

# %% [markdown]
# **According to the above results, the search queries based on “Artificial Intelligence” are mostly done in Ethiopia.**

# %% [markdown]
# **We can also visualize this data using a bar chart**

# %%
data.reset_index().plot(x="geoName", 
                        y="Artificial Intelligence", 
                        figsize=(15,12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# **Machine Learning has been the focus of so many companies and students for the last 3-4 years.**

# %% [markdown]
# **Let’s have a look at the trend of searches to see how the total search queries based on “Machine Learning” increased or decreased on Google.**

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Artificial Intelligence'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Artificial Intelligence'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Artificial Intelligence', 
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel
# Out:
# <function matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)>
